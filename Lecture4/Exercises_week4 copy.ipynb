# %% [markdown]
# # Week 4: Measurements
#
# This week, we want to get our hands dirty understanding how to handle canonical forms to do measurements of observables.

# %% [markdown]
# ## Exercise 1: Canonical forms
#
# **1)** Write a function that, given an input MPS brings it into a left canonical form;
#
# **2)** Do the same thing for the right canonical form;
#
# **3)** Write a function that brings the MPS into a mixed canonical form with an orthogonality center on site $i$;
#
# **4)** Write a function that, given a MPS with an orthogonality center on site $i$, moves the orthogonality center to site $j$;

# %%
using Pkg
Pkg.activate("../")
using ITensors
using ITensorMPS
using Plots
using LinearAlgebra
# Out:
#   Activating project at `c:\Users\mariu\GithubCloneTN\TN_Notebooks`

# %%
nn = 20
jj=1.0
system = siteinds("S=1/2",nn)
#Prepare the initial state as a product state with "Up" on the first site and "Dn" on the rest of the sites
psi0= MPS(ComplexF64,system,[(j==1) ? "Up" : "Dn" for j in 1:nn]);
psi0copy = deepcopy(psi0)
# Out:
# 20-element MPS:
#  ((dim=2|id=184|"S=1/2,Site,n=1"), (dim=1|id=375|"Link,l=1"))
#  ((dim=1|id=375|"Link,l=1"), (dim=2|id=190|"S=1/2,Site,n=2"), (dim=1|id=946|"Link,l=2"))
#  ((dim=1|id=946|"Link,l=2"), (dim=2|id=30|"S=1/2,Site,n=3"), (dim=1|id=971|"Link,l=3"))
#  ((dim=1|id=971|"Link,l=3"), (dim=2|id=984|"S=1/2,Site,n=4"), (dim=1|id=345|"Link,l=4"))
#  ((dim=1|id=345|"Link,l=4"), (dim=2|id=836|"S=1/2,Site,n=5"), (dim=1|id=585|"Link,l=5"))
#  ((dim=1|id=585|"Link,l=5"), (dim=2|id=215|"S=1/2,Site,n=6"), (dim=1|id=496|"Link,l=6"))
#  ((dim=1|id=496|"Link,l=6"), (dim=2|id=307|"S=1/2,Site,n=7"), (dim=1|id=168|"Link,l=7"))
#  ((dim=1|id=168|"Link,l=7"), (dim=2|id=746|"S=1/2,Site,n=8"), (dim=1|id=176|"Link,l=8"))
#  ((dim=1|id=176|"Link,l=8"), (dim=2|id=798|"S=1/2,Site,n=9"), (dim=1|id=987|"Link,l=9"))
#  ((dim=1|id=987|"Link,l=9"), (dim=2|id=412|"S=1/2,Site,n=10"), (dim=1|id=945|"Link,l=10"))
#  ((dim=1|id=945|"Link,l=10"), (dim=2|id=432|"S=1/2,Site,n=11"), (dim=1|id=527|"Link,l=11"))
#  ((dim=1|id=527|"Link,l=11"), (dim=2|id=467|"S=1/2,Site,n=12"), (dim=1|id=927|"Link,l=12"))
#  ((dim=1|id=927|"Link,l=12"), (dim=2|id=592|"S=1/2,Site,n=13"), (dim=1|id=668|"Link,l=13"))
#  ((dim=1|id=668|"Link,l=13"), (dim=2|id=538|"S=1/2,Site,n=14"), (dim=1|id=179|"Link,l=14"))
#  ((dim=1|id=179|"Link,l=14"), (dim=2|id=822|"S=1/2,Site,n=15"), (dim=1|id=720|"Link,l=15"))
#  ((dim=1|id=720|"Link,l=15"), (dim=2|id=188|"S=1/2,Site,n=16"), (dim=1|id=810|"Link,l=16"))
#  ((dim=1|id=810|"Link,l=16"), (dim=2|id=112|"S=1/2,Site,n=17"), (dim=1|id=431|"Link,l=17"))
#  ((dim=1|id=431|"Link,l=17"), (dim=2|id=745|"S=1/2,Site,n=18"), (dim=1|id=791|"Link,l=18"))
#  ((dim=1|id=791|"Link,l=18"), (dim=2|id=204|"S=1/2,Site,n=19"), (dim=1|id=523|"Link,l=19"))
#  ((dim=1|id=523|"Link,l=19"), (dim=2|id=324|"S=1/2,Site,n=20"))

# %%
psi0
# Out:
# 20-element MPS:
#  ((dim=2|id=184|"S=1/2,Site,n=1"), (dim=1|id=375|"Link,l=1"))
#  ((dim=1|id=375|"Link,l=1"), (dim=2|id=190|"S=1/2,Site,n=2"), (dim=1|id=946|"Link,l=2"))
#  ((dim=1|id=946|"Link,l=2"), (dim=2|id=30|"S=1/2,Site,n=3"), (dim=1|id=971|"Link,l=3"))
#  ((dim=1|id=971|"Link,l=3"), (dim=2|id=984|"S=1/2,Site,n=4"), (dim=1|id=345|"Link,l=4"))
#  ((dim=1|id=345|"Link,l=4"), (dim=2|id=836|"S=1/2,Site,n=5"), (dim=1|id=585|"Link,l=5"))
#  ((dim=1|id=585|"Link,l=5"), (dim=2|id=215|"S=1/2,Site,n=6"), (dim=1|id=496|"Link,l=6"))
#  ((dim=1|id=496|"Link,l=6"), (dim=2|id=307|"S=1/2,Site,n=7"), (dim=1|id=168|"Link,l=7"))
#  ((dim=1|id=168|"Link,l=7"), (dim=2|id=746|"S=1/2,Site,n=8"), (dim=1|id=176|"Link,l=8"))
#  ((dim=1|id=176|"Link,l=8"), (dim=2|id=798|"S=1/2,Site,n=9"), (dim=1|id=987|"Link,l=9"))
#  ((dim=1|id=987|"Link,l=9"), (dim=2|id=412|"S=1/2,Site,n=10"), (dim=1|id=945|"Link,l=10"))
#  ((dim=1|id=945|"Link,l=10"), (dim=2|id=432|"S=1/2,Site,n=11"), (dim=1|id=527|"Link,l=11"))
#  ((dim=1|id=527|"Link,l=11"), (dim=2|id=467|"S=1/2,Site,n=12"), (dim=1|id=927|"Link,l=12"))
#  ((dim=1|id=927|"Link,l=12"), (dim=2|id=592|"S=1/2,Site,n=13"), (dim=1|id=668|"Link,l=13"))
#  ((dim=1|id=668|"Link,l=13"), (dim=2|id=538|"S=1/2,Site,n=14"), (dim=1|id=179|"Link,l=14"))
#  ((dim=1|id=179|"Link,l=14"), (dim=2|id=822|"S=1/2,Site,n=15"), (dim=1|id=720|"Link,l=15"))
#  ((dim=1|id=720|"Link,l=15"), (dim=2|id=188|"S=1/2,Site,n=16"), (dim=1|id=810|"Link,l=16"))
#  ((dim=1|id=810|"Link,l=16"), (dim=2|id=112|"S=1/2,Site,n=17"), (dim=1|id=431|"Link,l=17"))
#  ((dim=1|id=431|"Link,l=17"), (dim=2|id=745|"S=1/2,Site,n=18"), (dim=1|id=791|"Link,l=18"))
#  ((dim=1|id=791|"Link,l=18"), (dim=2|id=204|"S=1/2,Site,n=19"), (dim=1|id=523|"Link,l=19"))
#  ((dim=1|id=523|"Link,l=19"), (dim=2|id=324|"S=1/2,Site,n=20"))

# %%
inds(psi0[1])
# Out:
# ((dim=2|id=184|"S=1/2,Site,n=1"), (dim=1|id=375|"Link,l=1"))

# %%
uu, s, vv = svd(psi0[1], inds(psi0[1])[1])
# Out:
# ITensors.TruncSVD(ITensor ord=2
# Dim 1: (dim=2|id=184|"S=1/2,Site,n=1")
# Dim 2: (dim=1|id=682|"Link,u")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}
#  2×1
#  1.0 + 0.0im
#  0.0 + 0.0im
# , ITensor ord=2
# Dim 1: (dim=1|id=682|"Link,u")
# Dim 2: (dim=1|id=260|"Link,v")
# NDTensors.Diag{Float64, Vector{Float64}}
#  1×1
#  1.0
# , ITensor ord=2
# Dim 1: (dim=1|id=375|"Link,l=1")
# Dim 2: (dim=1|id=260|"Link,v")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}
#  1×1
#  1.0 + 0.0im
# , Spectrum{Vector{Float64}, Float64}([1.0], 0.0), (dim=1|id=682|"Link,u"), (dim=1|id=260|"Link,v"))

# %%
uu
# Out:
# ITensor ord=2 (dim=2|id=184|"S=1/2,Site,n=1") (dim=1|id=682|"Link,u")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}

# %%
s
# Out:
# ITensor ord=2 (dim=1|id=682|"Link,u") (dim=1|id=260|"Link,v")
# NDTensors.Diag{Float64, Vector{Float64}}

# %%
vv
# Out:
# ITensor ord=2 (dim=1|id=375|"Link,l=1") (dim=1|id=260|"Link,v")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}

# %%
new2 = s*vv*psi0[2]
# Out:
# ITensor ord=3 (dim=1|id=682|"Link,u") (dim=2|id=190|"S=1/2,Site,n=2") (dim=1|id=946|"Link,l=2")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}

# %%
psi0[1] = uu
# Out:
# ITensor ord=2 (dim=2|id=184|"S=1/2,Site,n=1") (dim=1|id=682|"Link,u")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}

# %%
psi0[2] = new2
# Out:
# ITensor ord=3 (dim=1|id=682|"Link,u") (dim=2|id=190|"S=1/2,Site,n=2") (dim=1|id=946|"Link,l=2")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}

# %%
for i in 2:nn-1
    uu, s, vv = svd(psi0[i], inds(psi0[i])[1:2])
    newIPlus = s*vv*psi0[i+1]
    psi0[i] = uu
    psi0[i+1] = newIPlus
end

# %%
uu, s, vv = svd(psi0[nn], inds(psi0[nn])[1])
# Out:
# ITensors.TruncSVD(ITensor ord=2
# Dim 1: (dim=1|id=435|"Link,u")
# Dim 2: (dim=1|id=28|"Link,u")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}
#  1×1
#  -1.0 + 0.0im
# , ITensor ord=2
# Dim 1: (dim=1|id=28|"Link,u")
# Dim 2: (dim=1|id=645|"Link,v")
# NDTensors.Diag{Float64, Vector{Float64}}
#  1×1
#  1.0
# , ITensor ord=2
# Dim 1: (dim=2|id=324|"S=1/2,Site,n=20")
# Dim 2: (dim=1|id=645|"Link,v")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}
#  2×1
#   0.0 + 0.0im
#  -1.0 + 0.0im
# , Spectrum{Vector{Float64}, Float64}([1.0], 0.0), (dim=1|id=28|"Link,u"), (dim=1|id=645|"Link,v"))

# %%
psi0 ≈ psi0copy
# Out:
# true

# %%
typeof(length(psi0))
# Out:
# Int64

# %%
function leftCanonical(state)
    nn = length(state)
    uu, s, vv = svd(state[1], inds(state[1])[1])

    new2 = s*vv*state[2]
    state[1] = uu
    state[2] = new2
    
    for i in 2:nn-1
        uu, s, vv = svd(state[i], inds(state[i])[1:2])
        newIPlus = s*vv*state[i+1]
        state[i] = uu
        state[i+1] = newIPlus
    end
    return state
end
# Out:
# leftCanonical (generic function with 1 method)

# %%
psi0
# Out:
# 20-element MPS:
#  ((dim=2|id=184|"S=1/2,Site,n=1"), (dim=1|id=682|"Link,u"))
#  ((dim=1|id=682|"Link,u"), (dim=2|id=190|"S=1/2,Site,n=2"), (dim=1|id=691|"Link,u"))
#  ((dim=1|id=691|"Link,u"), (dim=2|id=30|"S=1/2,Site,n=3"), (dim=1|id=822|"Link,u"))
#  ((dim=1|id=822|"Link,u"), (dim=2|id=984|"S=1/2,Site,n=4"), (dim=1|id=205|"Link,u"))
#  ((dim=1|id=205|"Link,u"), (dim=2|id=836|"S=1/2,Site,n=5"), (dim=1|id=53|"Link,u"))
#  ((dim=1|id=53|"Link,u"), (dim=2|id=215|"S=1/2,Site,n=6"), (dim=1|id=283|"Link,u"))
#  ((dim=1|id=283|"Link,u"), (dim=2|id=307|"S=1/2,Site,n=7"), (dim=1|id=554|"Link,u"))
#  ((dim=1|id=554|"Link,u"), (dim=2|id=746|"S=1/2,Site,n=8"), (dim=1|id=165|"Link,u"))
#  ((dim=1|id=165|"Link,u"), (dim=2|id=798|"S=1/2,Site,n=9"), (dim=1|id=330|"Link,u"))
#  ((dim=1|id=330|"Link,u"), (dim=2|id=412|"S=1/2,Site,n=10"), (dim=1|id=945|"Link,u"))
#  ((dim=1|id=945|"Link,u"), (dim=2|id=432|"S=1/2,Site,n=11"), (dim=1|id=823|"Link,u"))
#  ((dim=1|id=823|"Link,u"), (dim=2|id=467|"S=1/2,Site,n=12"), (dim=1|id=54|"Link,u"))
#  ((dim=1|id=54|"Link,u"), (dim=2|id=592|"S=1/2,Site,n=13"), (dim=1|id=543|"Link,u"))
#  ((dim=1|id=543|"Link,u"), (dim=2|id=538|"S=1/2,Site,n=14"), (dim=1|id=211|"Link,u"))
#  ((dim=1|id=211|"Link,u"), (dim=2|id=822|"S=1/2,Site,n=15"), (dim=1|id=295|"Link,u"))
#  ((dim=1|id=295|"Link,u"), (dim=2|id=188|"S=1/2,Site,n=16"), (dim=1|id=778|"Link,u"))
#  ((dim=1|id=778|"Link,u"), (dim=2|id=112|"S=1/2,Site,n=17"), (dim=1|id=198|"Link,u"))
#  ((dim=1|id=198|"Link,u"), (dim=2|id=745|"S=1/2,Site,n=18"), (dim=1|id=656|"Link,u"))
#  ((dim=1|id=656|"Link,u"), (dim=2|id=204|"S=1/2,Site,n=19"), (dim=1|id=435|"Link,u"))
#  ((dim=1|id=435|"Link,u"), (dim=2|id=324|"S=1/2,Site,n=20"))

# %%
psiL = leftCanonical(psi0)
# Out:
# 20-element MPS:
#  ((dim=2|id=184|"S=1/2,Site,n=1"), (dim=1|id=46|"Link,u"))
#  ((dim=1|id=46|"Link,u"), (dim=2|id=190|"S=1/2,Site,n=2"), (dim=1|id=745|"Link,u"))
#  ((dim=1|id=745|"Link,u"), (dim=2|id=30|"S=1/2,Site,n=3"), (dim=1|id=15|"Link,u"))
#  ((dim=1|id=15|"Link,u"), (dim=2|id=984|"S=1/2,Site,n=4"), (dim=1|id=862|"Link,u"))
#  ((dim=1|id=862|"Link,u"), (dim=2|id=836|"S=1/2,Site,n=5"), (dim=1|id=450|"Link,u"))
#  ((dim=1|id=450|"Link,u"), (dim=2|id=215|"S=1/2,Site,n=6"), (dim=1|id=353|"Link,u"))
#  ((dim=1|id=353|"Link,u"), (dim=2|id=307|"S=1/2,Site,n=7"), (dim=1|id=543|"Link,u"))
#  ((dim=1|id=543|"Link,u"), (dim=2|id=746|"S=1/2,Site,n=8"), (dim=1|id=238|"Link,u"))
#  ((dim=1|id=238|"Link,u"), (dim=2|id=798|"S=1/2,Site,n=9"), (dim=1|id=987|"Link,u"))
#  ((dim=1|id=987|"Link,u"), (dim=2|id=412|"S=1/2,Site,n=10"), (dim=1|id=184|"Link,u"))
#  ((dim=1|id=184|"Link,u"), (dim=2|id=432|"S=1/2,Site,n=11"), (dim=1|id=755|"Link,u"))
#  ((dim=1|id=755|"Link,u"), (dim=2|id=467|"S=1/2,Site,n=12"), (dim=1|id=981|"Link,u"))
#  ((dim=1|id=981|"Link,u"), (dim=2|id=592|"S=1/2,Site,n=13"), (dim=1|id=962|"Link,u"))
#  ((dim=1|id=962|"Link,u"), (dim=2|id=538|"S=1/2,Site,n=14"), (dim=1|id=937|"Link,u"))
#  ((dim=1|id=937|"Link,u"), (dim=2|id=822|"S=1/2,Site,n=15"), (dim=1|id=925|"Link,u"))
#  ((dim=1|id=925|"Link,u"), (dim=2|id=188|"S=1/2,Site,n=16"), (dim=1|id=6|"Link,u"))
#  ((dim=1|id=6|"Link,u"), (dim=2|id=112|"S=1/2,Site,n=17"), (dim=1|id=606|"Link,u"))
#  ((dim=1|id=606|"Link,u"), (dim=2|id=745|"S=1/2,Site,n=18"), (dim=1|id=449|"Link,u"))
#  ((dim=1|id=449|"Link,u"), (dim=2|id=204|"S=1/2,Site,n=19"), (dim=1|id=352|"Link,u"))
#  ((dim=1|id=352|"Link,u"), (dim=2|id=324|"S=1/2,Site,n=20"))

# %%
function rightCanonical(state)
    nn = length(state)
    uu, s, vv = svd(state[nn], commonind(state[nn], state[nn-1]))

    new2M = s*uu*state[nn-1]
    state[nn] = vv
    state[nn-1] = new2M
    
    for i in nn-1:-1:2
        uu, s, vv = svd(state[i], commonind(state[i], state[i-1]))
        newIPlus = s*uu*state[i-1]
        state[i] = vv
        state[i-1] = newIPlus
    end
    return state
end
# Out:
# rightCanonical (generic function with 1 method)

# %%
psi0copy
# Out:
# 20-element MPS:
#  ((dim=2|id=184|"S=1/2,Site,n=1"), (dim=1|id=375|"Link,l=1"))
#  ((dim=1|id=375|"Link,l=1"), (dim=2|id=190|"S=1/2,Site,n=2"), (dim=1|id=946|"Link,l=2"))
#  ((dim=1|id=946|"Link,l=2"), (dim=2|id=30|"S=1/2,Site,n=3"), (dim=1|id=971|"Link,l=3"))
#  ((dim=1|id=971|"Link,l=3"), (dim=2|id=984|"S=1/2,Site,n=4"), (dim=1|id=345|"Link,l=4"))
#  ((dim=1|id=345|"Link,l=4"), (dim=2|id=836|"S=1/2,Site,n=5"), (dim=1|id=585|"Link,l=5"))
#  ((dim=1|id=585|"Link,l=5"), (dim=2|id=215|"S=1/2,Site,n=6"), (dim=1|id=496|"Link,l=6"))
#  ((dim=1|id=496|"Link,l=6"), (dim=2|id=307|"S=1/2,Site,n=7"), (dim=1|id=168|"Link,l=7"))
#  ((dim=1|id=168|"Link,l=7"), (dim=2|id=746|"S=1/2,Site,n=8"), (dim=1|id=176|"Link,l=8"))
#  ((dim=1|id=176|"Link,l=8"), (dim=2|id=798|"S=1/2,Site,n=9"), (dim=1|id=987|"Link,l=9"))
#  ((dim=1|id=987|"Link,l=9"), (dim=2|id=412|"S=1/2,Site,n=10"), (dim=1|id=945|"Link,l=10"))
#  ((dim=1|id=945|"Link,l=10"), (dim=2|id=432|"S=1/2,Site,n=11"), (dim=1|id=527|"Link,l=11"))
#  ((dim=1|id=527|"Link,l=11"), (dim=2|id=467|"S=1/2,Site,n=12"), (dim=1|id=927|"Link,l=12"))
#  ((dim=1|id=927|"Link,l=12"), (dim=2|id=592|"S=1/2,Site,n=13"), (dim=1|id=668|"Link,l=13"))
#  ((dim=1|id=668|"Link,l=13"), (dim=2|id=538|"S=1/2,Site,n=14"), (dim=1|id=179|"Link,l=14"))
#  ((dim=1|id=179|"Link,l=14"), (dim=2|id=822|"S=1/2,Site,n=15"), (dim=1|id=720|"Link,l=15"))
#  ((dim=1|id=720|"Link,l=15"), (dim=2|id=188|"S=1/2,Site,n=16"), (dim=1|id=810|"Link,l=16"))
#  ((dim=1|id=810|"Link,l=16"), (dim=2|id=112|"S=1/2,Site,n=17"), (dim=1|id=431|"Link,l=17"))
#  ((dim=1|id=431|"Link,l=17"), (dim=2|id=745|"S=1/2,Site,n=18"), (dim=1|id=791|"Link,l=18"))
#  ((dim=1|id=791|"Link,l=18"), (dim=2|id=204|"S=1/2,Site,n=19"), (dim=1|id=523|"Link,l=19"))
#  ((dim=1|id=523|"Link,l=19"), (dim=2|id=324|"S=1/2,Site,n=20"))

# %%
psiR = rightCanonical(psi0copy)
# Out:
# 20-element MPS:
#  ((dim=1|id=882|"Link,v"), (dim=2|id=184|"S=1/2,Site,n=1"))
#  ((dim=1|id=808|"Link,v"), (dim=2|id=190|"S=1/2,Site,n=2"), (dim=1|id=882|"Link,v"))
#  ((dim=1|id=229|"Link,v"), (dim=2|id=30|"S=1/2,Site,n=3"), (dim=1|id=808|"Link,v"))
#  ((dim=1|id=91|"Link,v"), (dim=2|id=984|"S=1/2,Site,n=4"), (dim=1|id=229|"Link,v"))
#  ((dim=1|id=276|"Link,v"), (dim=2|id=836|"S=1/2,Site,n=5"), (dim=1|id=91|"Link,v"))
#  ((dim=1|id=652|"Link,v"), (dim=2|id=215|"S=1/2,Site,n=6"), (dim=1|id=276|"Link,v"))
#  ((dim=1|id=628|"Link,v"), (dim=2|id=307|"S=1/2,Site,n=7"), (dim=1|id=652|"Link,v"))
#  ((dim=1|id=891|"Link,v"), (dim=2|id=746|"S=1/2,Site,n=8"), (dim=1|id=628|"Link,v"))
#  ((dim=1|id=721|"Link,v"), (dim=2|id=798|"S=1/2,Site,n=9"), (dim=1|id=891|"Link,v"))
#  ((dim=1|id=871|"Link,v"), (dim=2|id=412|"S=1/2,Site,n=10"), (dim=1|id=721|"Link,v"))
#  ((dim=1|id=160|"Link,v"), (dim=2|id=432|"S=1/2,Site,n=11"), (dim=1|id=871|"Link,v"))
#  ((dim=1|id=494|"Link,v"), (dim=2|id=467|"S=1/2,Site,n=12"), (dim=1|id=160|"Link,v"))
#  ((dim=1|id=348|"Link,v"), (dim=2|id=592|"S=1/2,Site,n=13"), (dim=1|id=494|"Link,v"))
#  ((dim=1|id=701|"Link,v"), (dim=2|id=538|"S=1/2,Site,n=14"), (dim=1|id=348|"Link,v"))
#  ((dim=1|id=682|"Link,v"), (dim=2|id=822|"S=1/2,Site,n=15"), (dim=1|id=701|"Link,v"))
#  ((dim=1|id=817|"Link,v"), (dim=2|id=188|"S=1/2,Site,n=16"), (dim=1|id=682|"Link,v"))
#  ((dim=1|id=963|"Link,v"), (dim=2|id=112|"S=1/2,Site,n=17"), (dim=1|id=817|"Link,v"))
#  ((dim=1|id=94|"Link,v"), (dim=2|id=745|"S=1/2,Site,n=18"), (dim=1|id=963|"Link,v"))
#  ((dim=1|id=17|"Link,v"), (dim=2|id=204|"S=1/2,Site,n=19"), (dim=1|id=94|"Link,v"))
#  ((dim=2|id=324|"S=1/2,Site,n=20"), (dim=1|id=17|"Link,v"))

# %% [markdown]
# ## Exercise 2: Expectation value of $S_z$
#
# **1)** Write a function that, given an input MPS compute the expectation value of $S_z$ on every sites;
#
# **2)** Create a random MPS with $N = 10$ spins and a bond dimension $D=4$ and measure $S_z$ with the function that you wrote in **1)**;
#
# **3)** Within `ITensor`, the expectation values of a local observable can be computed using the `expect` function that takes as an input a MPS and an operator. Compare the results you obbtained in **2)** with the function `expect(psi,"Sz")` that returns the expectation of $S_z$ on each site.

# %%
function expectSZ(state)
    indis = siteinds(state)
    nn = length(state)
    opsum = OpSum()
    for i in 1:nn
        opsum += "Sz", i
    end
    operatorSZ = MPO(opsum, indis)

    return inner(state', operatorSZ, state)
end
# Out:
# expectSZ (generic function with 1 method)

# %%
expectSZ(psi0)
# Out:
# -9.0 + 0.0im

# %%
# system
nn = 10
system = siteinds("S=1/2", nn)
# Out:
# 10-element Vector{Index{Int64}}:
#  (dim=2|id=305|"S=1/2,Site,n=1")
#  (dim=2|id=143|"S=1/2,Site,n=2")
#  (dim=2|id=988|"S=1/2,Site,n=3")
#  (dim=2|id=682|"S=1/2,Site,n=4")
#  (dim=2|id=322|"S=1/2,Site,n=5")
#  (dim=2|id=203|"S=1/2,Site,n=6")
#  (dim=2|id=338|"S=1/2,Site,n=7")
#  (dim=2|id=654|"S=1/2,Site,n=8")
#  (dim=2|id=871|"S=1/2,Site,n=9")
#  (dim=2|id=662|"S=1/2,Site,n=10")

# %%
# random MPS

randomMPS = random_mps(system, linkdims=4)
# Out:
# 10-element MPS:
#  ((dim=2|id=305|"S=1/2,Site,n=1"), (dim=4|id=819|"Link,l=1"))
#  ((dim=4|id=819|"Link,l=1"), (dim=2|id=143|"S=1/2,Site,n=2"), (dim=4|id=55|"Link,l=2"))
#  ((dim=4|id=55|"Link,l=2"), (dim=2|id=988|"S=1/2,Site,n=3"), (dim=4|id=15|"Link,l=3"))
#  ((dim=4|id=15|"Link,l=3"), (dim=2|id=682|"S=1/2,Site,n=4"), (dim=4|id=437|"Link,l=4"))
#  ((dim=4|id=437|"Link,l=4"), (dim=2|id=322|"S=1/2,Site,n=5"), (dim=4|id=524|"Link,l=5"))
#  ((dim=4|id=524|"Link,l=5"), (dim=2|id=203|"S=1/2,Site,n=6"), (dim=4|id=51|"Link,l=6"))
#  ((dim=4|id=51|"Link,l=6"), (dim=2|id=338|"S=1/2,Site,n=7"), (dim=4|id=361|"Link,l=7"))
#  ((dim=4|id=361|"Link,l=7"), (dim=2|id=654|"S=1/2,Site,n=8"), (dim=4|id=445|"Link,l=8"))
#  ((dim=4|id=445|"Link,l=8"), (dim=2|id=871|"S=1/2,Site,n=9"), (dim=2|id=191|"Link,l=9"))
#  ((dim=2|id=191|"Link,l=9"), (dim=2|id=662|"S=1/2,Site,n=10"))

# %%
meanSZ_random = expectSZ(randomMPS)
# Out:
# -0.6322357567911583

# %%
meanSZ_random2 = sum(expect(randomMPS, "Sz"))
# Out:
# -0.6322357567911583

# %% [markdown]
# ## Exercise 3: Two-point correlation function
#
# **1)** Write a function that computes the correlation function of $S^z_1$ and $S^z_i$ with $i> 1$;
#
# **2)** Lets us consider the following entangled state $\ket{\psi} = \left(\ket{\downarrow\downarrow\ldots\downarrow\uparrow} + \ket{\uparrow\downarrow\ldots\downarrow\downarrow}\right)/\sqrt{2}$.
# Compute its two-point $S_1^z$-$S_i^z$ correlation function;
#
# **3)** The function `correlation_matrix(psi,"Sz","Sz")` from `ITensors` returns the correlation matrix $\bra{\psi}S^z_i S^z_j \ket{\psi}$. Compare your results with `correlation_matrix`.

# %%
function correl1I(state, i)
    indis = siteinds(state)
    nn = length(state)
    opsum = OpSum()
    opsum += "Sz", 1, "Sz", i
    operatorSZ = MPO(opsum, indis)

    return inner(state', operatorSZ, state)
end
# Out:
# correl1I (generic function with 1 method)

# %%
psi1 = MPS(ComplexF64,system,[(j==nn) ? "Up" : "Dn" for j in 1:nn])
psi2 = MPS(ComplexF64,system,[(j==1) ? "Up" : "Dn" for j in 1:nn])
psi = 1/sqrt(2)*(psi1 + psi2)
# Out:
# 10-element MPS:
#  ((dim=2|id=305|"S=1/2,Site,n=1"), (dim=2|id=459|"Link,l=1"))
#  ((dim=2|id=143|"S=1/2,Site,n=2"), (dim=2|id=412|"Link,l=2"), (dim=2|id=459|"Link,l=1"))
#  ((dim=2|id=988|"S=1/2,Site,n=3"), (dim=2|id=514|"Link,l=3"), (dim=2|id=412|"Link,l=2"))
#  ((dim=2|id=682|"S=1/2,Site,n=4"), (dim=2|id=906|"Link,l=4"), (dim=2|id=514|"Link,l=3"))
#  ((dim=2|id=322|"S=1/2,Site,n=5"), (dim=2|id=192|"Link,l=5"), (dim=2|id=906|"Link,l=4"))
#  ((dim=2|id=203|"S=1/2,Site,n=6"), (dim=2|id=808|"Link,l=6"), (dim=2|id=192|"Link,l=5"))
#  ((dim=2|id=338|"S=1/2,Site,n=7"), (dim=2|id=327|"Link,l=7"), (dim=2|id=808|"Link,l=6"))
#  ((dim=2|id=654|"S=1/2,Site,n=8"), (dim=2|id=140|"Link,l=8"), (dim=2|id=327|"Link,l=7"))
#  ((dim=2|id=871|"S=1/2,Site,n=9"), (dim=2|id=580|"Link,l=9"), (dim=2|id=140|"Link,l=8"))
#  ((dim=2|id=662|"S=1/2,Site,n=10"), (dim=2|id=580|"Link,l=9"))

# %%
for i in 1:nn
    println(correl1I(psi, i))
end
# Out:
# 0.24999999999999994 + 0.0im
# 0.0 + 0.0im
# 0.0 + 0.0im
# 0.0 + 0.0im
# 0.0 + 0.0im
# 0.0 + 0.0im
# 0.0 + 0.0im
# 0.0 + 0.0im
# 0.0 + 0.0im
# -0.24999999999999994 + 0.0im

# %%
correlation_matrix(psi,"Sz","Sz")
# Out:
# 10×10 Matrix{ComplexF64}:
#   0.25+0.0im   0.0+0.0im   0.0+0.0im  …   0.0+0.0im   0.0+0.0im  -0.25+0.0im
#    0.0-0.0im  0.25+0.0im  0.25+0.0im     0.25+0.0im  0.25+0.0im    0.0+0.0im
#    0.0-0.0im  0.25-0.0im  0.25+0.0im     0.25+0.0im  0.25+0.0im    0.0+0.0im
#    0.0-0.0im  0.25-0.0im  0.25-0.0im     0.25+0.0im  0.25+0.0im    0.0+0.0im
#    0.0-0.0im  0.25-0.0im  0.25-0.0im     0.25+0.0im  0.25+0.0im    0.0+0.0im
#    0.0-0.0im  0.25-0.0im  0.25-0.0im  …  0.25+0.0im  0.25+0.0im    0.0+0.0im
#    0.0-0.0im  0.25-0.0im  0.25-0.0im     0.25+0.0im  0.25+0.0im    0.0+0.0im
#    0.0-0.0im  0.25-0.0im  0.25-0.0im     0.25+0.0im  0.25+0.0im    0.0+0.0im
#    0.0-0.0im  0.25-0.0im  0.25-0.0im     0.25-0.0im  0.25+0.0im    0.0+0.0im
#  -0.25-0.0im   0.0-0.0im   0.0-0.0im      0.0-0.0im   0.0-0.0im   0.25+0.0im

# %% [markdown]
# use first column

# %% [markdown]
# ## Exercise 4: Measurements as a Convergence Check
#
# Last week, in [MPO_ITensor.ipynb](../Lecture3/MPO_ITensor.ipynb), you used the 3rd order expansion of the evolution operator $exp(-i H \delta t)$ to compute the time-evolution of a MPS. This is an approximation that depends on the magnitude of the Hamiltonian matrix and the time-step $\delta t$.
# We know that for a closed system, the energy $\langle H \rangle$ is conserved. Thus, this expectation value can be used as a convergence check. If it doesn't stay constant, one should reduce $\delta t$ and/or add orders to the expansion.
#
# **1)** Compute the expectation value of the energy at each time step for an evolution using a 2nd order expansion;
#
# **2)** Compute the expectation value of the energy at each time step for an evolution using a 3rd order expansion and play with the value of $\delta t$.

# %%
nn = 20
jj=1.0
system = siteinds("S=1/2",nn)
#Prepare the initial state as a product state with "Up" on the first site and "Dn" on the rest of the sites
psi0= MPS(ComplexF64,system,[(j==1) ? "Up" : "Dn" for j in 1:nn]);
psi0copy = deepcopy(psi0)
# Out:
# 20-element MPS:
#  ((dim=2|id=68|"S=1/2,Site,n=1"), (dim=1|id=78|"Link,l=1"))
#  ((dim=1|id=78|"Link,l=1"), (dim=2|id=574|"S=1/2,Site,n=2"), (dim=1|id=88|"Link,l=2"))
#  ((dim=1|id=88|"Link,l=2"), (dim=2|id=820|"S=1/2,Site,n=3"), (dim=1|id=295|"Link,l=3"))
#  ((dim=1|id=295|"Link,l=3"), (dim=2|id=443|"S=1/2,Site,n=4"), (dim=1|id=172|"Link,l=4"))
#  ((dim=1|id=172|"Link,l=4"), (dim=2|id=978|"S=1/2,Site,n=5"), (dim=1|id=618|"Link,l=5"))
#  ((dim=1|id=618|"Link,l=5"), (dim=2|id=577|"S=1/2,Site,n=6"), (dim=1|id=873|"Link,l=6"))
#  ((dim=1|id=873|"Link,l=6"), (dim=2|id=769|"S=1/2,Site,n=7"), (dim=1|id=464|"Link,l=7"))
#  ((dim=1|id=464|"Link,l=7"), (dim=2|id=528|"S=1/2,Site,n=8"), (dim=1|id=120|"Link,l=8"))
#  ((dim=1|id=120|"Link,l=8"), (dim=2|id=453|"S=1/2,Site,n=9"), (dim=1|id=504|"Link,l=9"))
#  ((dim=1|id=504|"Link,l=9"), (dim=2|id=507|"S=1/2,Site,n=10"), (dim=1|id=602|"Link,l=10"))
#  ((dim=1|id=602|"Link,l=10"), (dim=2|id=715|"S=1/2,Site,n=11"), (dim=1|id=773|"Link,l=11"))
#  ((dim=1|id=773|"Link,l=11"), (dim=2|id=258|"S=1/2,Site,n=12"), (dim=1|id=207|"Link,l=12"))
#  ((dim=1|id=207|"Link,l=12"), (dim=2|id=173|"S=1/2,Site,n=13"), (dim=1|id=557|"Link,l=13"))
#  ((dim=1|id=557|"Link,l=13"), (dim=2|id=481|"S=1/2,Site,n=14"), (dim=1|id=951|"Link,l=14"))
#  ((dim=1|id=951|"Link,l=14"), (dim=2|id=910|"S=1/2,Site,n=15"), (dim=1|id=870|"Link,l=15"))
#  ((dim=1|id=870|"Link,l=15"), (dim=2|id=330|"S=1/2,Site,n=16"), (dim=1|id=965|"Link,l=16"))
#  ((dim=1|id=965|"Link,l=16"), (dim=2|id=832|"S=1/2,Site,n=17"), (dim=1|id=946|"Link,l=17"))
#  ((dim=1|id=946|"Link,l=17"), (dim=2|id=221|"S=1/2,Site,n=18"), (dim=1|id=811|"Link,l=18"))
#  ((dim=1|id=811|"Link,l=18"), (dim=2|id=41|"S=1/2,Site,n=19"), (dim=1|id=605|"Link,l=19"))
#  ((dim=1|id=605|"Link,l=19"), (dim=2|id=639|"S=1/2,Site,n=20"))

# %%
# define a hamiltonian
h = -0.5
opsum = OpSum()
for bond in 1:nn-1
    #note that the sintax allows for constants to appear before the operator string
    opsum += -1. * jj, "S-", bond, "S+", bond+1
    opsum += -1. * jj, "S+", bond, "S-", bond+1
end

ham = MPO(opsum, system)
# Out:
# 20-element MPO:
#  ((dim=4|id=297|"Link,l=1"), (dim=2|id=68|"S=1/2,Site,n=1")', (dim=2|id=68|"S=1/2,Site,n=1"))
#  ((dim=4|id=297|"Link,l=1"), (dim=4|id=391|"Link,l=2"), (dim=2|id=574|"S=1/2,Site,n=2")', (dim=2|id=574|"S=1/2,Site,n=2"))
#  ((dim=4|id=391|"Link,l=2"), (dim=4|id=126|"Link,l=3"), (dim=2|id=820|"S=1/2,Site,n=3")', (dim=2|id=820|"S=1/2,Site,n=3"))
#  ((dim=4|id=126|"Link,l=3"), (dim=4|id=36|"Link,l=4"), (dim=2|id=443|"S=1/2,Site,n=4")', (dim=2|id=443|"S=1/2,Site,n=4"))
#  ((dim=4|id=36|"Link,l=4"), (dim=4|id=924|"Link,l=5"), (dim=2|id=978|"S=1/2,Site,n=5")', (dim=2|id=978|"S=1/2,Site,n=5"))
#  ((dim=4|id=924|"Link,l=5"), (dim=4|id=157|"Link,l=6"), (dim=2|id=577|"S=1/2,Site,n=6")', (dim=2|id=577|"S=1/2,Site,n=6"))
#  ((dim=4|id=157|"Link,l=6"), (dim=4|id=147|"Link,l=7"), (dim=2|id=769|"S=1/2,Site,n=7")', (dim=2|id=769|"S=1/2,Site,n=7"))
#  ((dim=4|id=147|"Link,l=7"), (dim=4|id=966|"Link,l=8"), (dim=2|id=528|"S=1/2,Site,n=8")', (dim=2|id=528|"S=1/2,Site,n=8"))
#  ((dim=4|id=966|"Link,l=8"), (dim=4|id=557|"Link,l=9"), (dim=2|id=453|"S=1/2,Site,n=9")', (dim=2|id=453|"S=1/2,Site,n=9"))
#  ((dim=4|id=557|"Link,l=9"), (dim=4|id=824|"Link,l=10"), (dim=2|id=507|"S=1/2,Site,n=10")', (dim=2|id=507|"S=1/2,Site,n=10"))
#  ((dim=4|id=824|"Link,l=10"), (dim=4|id=808|"Link,l=11"), (dim=2|id=715|"S=1/2,Site,n=11")', (dim=2|id=715|"S=1/2,Site,n=11"))
#  ((dim=4|id=808|"Link,l=11"), (dim=4|id=286|"Link,l=12"), (dim=2|id=258|"S=1/2,Site,n=12")', (dim=2|id=258|"S=1/2,Site,n=12"))
#  ((dim=4|id=286|"Link,l=12"), (dim=4|id=767|"Link,l=13"), (dim=2|id=173|"S=1/2,Site,n=13")', (dim=2|id=173|"S=1/2,Site,n=13"))
#  ((dim=4|id=767|"Link,l=13"), (dim=4|id=817|"Link,l=14"), (dim=2|id=481|"S=1/2,Site,n=14")', (dim=2|id=481|"S=1/2,Site,n=14"))
#  ((dim=4|id=817|"Link,l=14"), (dim=4|id=805|"Link,l=15"), (dim=2|id=910|"S=1/2,Site,n=15")', (dim=2|id=910|"S=1/2,Site,n=15"))
#  ((dim=4|id=805|"Link,l=15"), (dim=4|id=407|"Link,l=16"), (dim=2|id=330|"S=1/2,Site,n=16")', (dim=2|id=330|"S=1/2,Site,n=16"))
#  ((dim=4|id=407|"Link,l=16"), (dim=4|id=447|"Link,l=17"), (dim=2|id=832|"S=1/2,Site,n=17")', (dim=2|id=832|"S=1/2,Site,n=17"))
#  ((dim=4|id=447|"Link,l=17"), (dim=4|id=194|"Link,l=18"), (dim=2|id=221|"S=1/2,Site,n=18")', (dim=2|id=221|"S=1/2,Site,n=18"))
#  ((dim=4|id=194|"Link,l=18"), (dim=4|id=2|"Link,l=19"), (dim=2|id=41|"S=1/2,Site,n=19")', (dim=2|id=41|"S=1/2,Site,n=19"))
#  ((dim=4|id=2|"Link,l=19"), (dim=2|id=639|"S=1/2,Site,n=20")', (dim=2|id=639|"S=1/2,Site,n=20"))

# %%
deltat = 0.5
nsteps = Int(round(10/deltat))
hdeltat = deltat * ham
#build an MPO with the operator "Id" on each site
theOne = MPO(system,"Id")
factor(k) = (-1im)^k / factorial(k)
#As not to have all the indices of hdeltat contracted with each other, we prime the second one and then we contract the first index of the second one with the first index of the first one, and then we lower the second prime level to first prime level.
h2 = mapprime(prime(hdeltat)*hdeltat,2 =>1)
h3 = mapprime(prime(hdeltat) * h2,2 =>1)
terms = [theOne, factor(1)*hdeltat, factor(2)*h2, factor(3)*h3];
appo = terms[1];
for t in terms[2:end]
    appo = t + appo
end
h3thOrder = appo;

terms = [theOne, factor(1)*hdeltat, factor(2)*h2];
appo = terms[1];
for t in terms[2:end]
    appo = t + appo
end
h2thOrder = appo;
#h4thOrder = +(terms...; cutoff=1e-18);
# Out:
# 20-element MPO:
#  ((dim=2|id=68|"S=1/2,Site,n=1")', (dim=2|id=68|"S=1/2,Site,n=1"), (dim=7|id=274|"Link,l=1"))
#  ((dim=2|id=574|"S=1/2,Site,n=2")', (dim=2|id=574|"S=1/2,Site,n=2"), (dim=8|id=229|"Link,l=2"), (dim=7|id=274|"Link,l=1"))
#  ((dim=2|id=820|"S=1/2,Site,n=3")', (dim=2|id=820|"S=1/2,Site,n=3"), (dim=8|id=986|"Link,l=3"), (dim=8|id=229|"Link,l=2"))
#  ((dim=2|id=443|"S=1/2,Site,n=4")', (dim=2|id=443|"S=1/2,Site,n=4"), (dim=8|id=967|"Link,l=4"), (dim=8|id=986|"Link,l=3"))
#  ((dim=2|id=978|"S=1/2,Site,n=5")', (dim=2|id=978|"S=1/2,Site,n=5"), (dim=8|id=677|"Link,l=5"), (dim=8|id=967|"Link,l=4"))
#  ((dim=2|id=577|"S=1/2,Site,n=6")', (dim=2|id=577|"S=1/2,Site,n=6"), (dim=8|id=809|"Link,l=6"), (dim=8|id=677|"Link,l=5"))
#  ((dim=2|id=769|"S=1/2,Site,n=7")', (dim=2|id=769|"S=1/2,Site,n=7"), (dim=8|id=594|"Link,l=7"), (dim=8|id=809|"Link,l=6"))
#  ((dim=2|id=528|"S=1/2,Site,n=8")', (dim=2|id=528|"S=1/2,Site,n=8"), (dim=8|id=730|"Link,l=8"), (dim=8|id=594|"Link,l=7"))
#  ((dim=2|id=453|"S=1/2,Site,n=9")', (dim=2|id=453|"S=1/2,Site,n=9"), (dim=8|id=918|"Link,l=9"), (dim=8|id=730|"Link,l=8"))
#  ((dim=2|id=507|"S=1/2,Site,n=10")', (dim=2|id=507|"S=1/2,Site,n=10"), (dim=8|id=804|"Link,l=10"), (dim=8|id=918|"Link,l=9"))
#  ((dim=2|id=715|"S=1/2,Site,n=11")', (dim=2|id=715|"S=1/2,Site,n=11"), (dim=8|id=593|"Link,l=11"), (dim=8|id=804|"Link,l=10"))
#  ((dim=2|id=258|"S=1/2,Site,n=12")', (dim=2|id=258|"S=1/2,Site,n=12"), (dim=8|id=922|"Link,l=12"), (dim=8|id=593|"Link,l=11"))
#  ((dim=2|id=173|"S=1/2,Site,n=13")', (dim=2|id=173|"S=1/2,Site,n=13"), (dim=8|id=305|"Link,l=13"), (dim=8|id=922|"Link,l=12"))
#  ((dim=2|id=481|"S=1/2,Site,n=14")', (dim=2|id=481|"S=1/2,Site,n=14"), (dim=8|id=870|"Link,l=14"), (dim=8|id=305|"Link,l=13"))
#  ((dim=2|id=910|"S=1/2,Site,n=15")', (dim=2|id=910|"S=1/2,Site,n=15"), (dim=8|id=892|"Link,l=15"), (dim=8|id=870|"Link,l=14"))
#  ((dim=2|id=330|"S=1/2,Site,n=16")', (dim=2|id=330|"S=1/2,Site,n=16"), (dim=8|id=117|"Link,l=16"), (dim=8|id=892|"Link,l=15"))
#  ((dim=2|id=832|"S=1/2,Site,n=17")', (dim=2|id=832|"S=1/2,Site,n=17"), (dim=8|id=63|"Link,l=17"), (dim=8|id=117|"Link,l=16"))
#  ((dim=2|id=221|"S=1/2,Site,n=18")', (dim=2|id=221|"S=1/2,Site,n=18"), (dim=8|id=842|"Link,l=18"), (dim=8|id=63|"Link,l=17"))
#  ((dim=2|id=41|"S=1/2,Site,n=19")', (dim=2|id=41|"S=1/2,Site,n=19"), (dim=4|id=441|"Link,l=19"), (dim=8|id=842|"Link,l=18"))
#  ((dim=2|id=639|"S=1/2,Site,n=20")', (dim=2|id=639|"S=1/2,Site,n=20"), (dim=4|id=441|"Link,l=19"))

# %%
evolved3 = Vector{MPS}()
push!(evolved3, psi0)
for j=2:nsteps
    push!(evolved3, noprime(h3thOrder * evolved3[end]))
end

# %%
function expectH(state, ham)
    return inner(state', ham, state)
end
# Out:
# expectH (generic function with 1 method)

# %%
for state in evolved3
    println(expectH(state, h3thOrder))
end
# Out:
# 0.8749999999999797 + 1.427841166874679e-14im
# 0.8692491319443966 + 2.23509718651701e-14im
# 0.8636350984925826 + 2.879098928642559e-14im
# 0.8581534711993153 + 3.4567636134979996e-14im
# 0.8527999869908532 + 4.055145377330666e-14im
# 0.8475705414846977 + 4.7059612438361975e-14im
# 0.8424611824965494 + 5.494571299204292e-14im
# 0.8374681039467621 + 6.218467620884218e-14im
# 0.8325876399705491 + 7.000506248934197e-14im
# 0.8278162592651759 + 7.661919242476666e-14im
# 0.8231505597069876 + 8.25951232796704e-14im
# 0.8185872631818247 + 8.818043014715921e-14im
# 0.8141232106373547 + 9.188644845008799e-14im
# 0.8097553573450896 + 9.290622860201906e-14im
# 0.8054807683625269 + 8.950028116902226e-14im
# 0.8012966141865441 + 8.306474675841627e-14im
# 0.797200166589628 + 7.5623020215701e-14im
# 0.7931887946309019 + 6.816964527589509e-14im
# 0.7892599608344365 + 6.118716644465394e-14im
# 0.7854112175274083 + 5.4864966736456466e-14im

# %%
evolved2 = Vector{MPS}()
push!(evolved2, psi0)
for j=2:nsteps
    push!(evolved2, noprime(h2thOrder * evolved2[end]))
end

# %%
for state in evolved2
    println(expectH(state, h2thOrder))
end
# Out:
# 0.8749999999999777 - 1.091172281719171e-16im
# 0.8964843749999429 + 8.229446768938665e-16im
# 0.920104980468655 + 1.6502311641462448e-15im
# 0.9461607933043155 + 2.767538329096609e-15im
# 0.9749998003242839 + 4.39921325194281e-15im
# 1.0070277971679316 + 5.041830936720791e-15im
# 1.0427188628452746 + 7.645100937069146e-15im
# 1.0826278424845441 + 9.934209233993275e-15im
# 1.1274052388732358 + 1.2900318238137821e-14im
# 1.1778149956694375 + 1.5868105622264687e-14im
# 1.2347557547799437 + 1.8923889608025782e-14im
# 1.2992862910394638 + 2.2009875075197253e-14im
# 1.3726559729930863 + 2.3828095158524824e-14im
# 1.4563412763672625 + 2.716641398433292e-14im
# 1.5520895908589682 + 3.07049593728032e-14im
# 1.6619718216621446 + 3.5011044166045056e-14im
# 1.7884456032953728 + 4.0092034509983665e-14im
# 1.9344313272935694 + 4.511733868450829e-14im
# 2.1034036518756114 + 5.056415355864097e-14im
# 2.2995017287955446 + 5.952530135466816e-14im
